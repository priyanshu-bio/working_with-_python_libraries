# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

dataa = pd.read_csv("crop_yield_dataset.csv")


crop_name = input("enter your crop name").capitalize()
while crop_name not in dataa["Crop_Type"].unique():
    print("Invalid crop name. Please try again.")
    crop_name = input("enter your crop name").capitalize()
crop_df = dataa[dataa["Crop_Type"] == crop_name]


numeric_data = crop_df.select_dtypes(include=["number"])
correlation_matrix = numeric_data.corr()


plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title(f"Correlation Matrix for {crop_name}")
plt.savefig("seaborn_heatmap.png", bbox_inches="tight")
plt.show()




selected_columns = ["Temperature", "Humidity", "Crop_Yield", "Soil_pH", "Soil_Quality"]
sns.pairplot(crop_df[selected_columns])
pairplot_fig.savefig("seaborn_pairplot.png")
plt.show()
